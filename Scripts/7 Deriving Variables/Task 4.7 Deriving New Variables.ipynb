# %% [markdown]
# # Importing Libraries and Dataframes

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
#Importing data from 'ords_prods_merged'
path = r'/Users/marialuciaguarita/Python Careerfoundry Project 1'
df_ords_prods_prods_combined = pd.read_pickle(os.path.join(path,'Data','Prepared Data','orders_products_products_combined.pkl'))

# %%
#Checking imported dataframe and formatting
df_ords_prods_prods_combined = df_ords_prods_prods_combined[:1000000]
df_ords_prods_prods_combined.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'add_to_cart_order',
#        'reordered', '_merge', 'merge_2'],
#       dtype='object')

# %%
df_ords_prods_prods_combined.shape
# Out:
# (1000000, 16)

# %%
df_ords_prods_prods_combined.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_prods_combined = df_ords_prods_prods_combined.drop (columns = ['merge_2','_merge'])

# %%
df_ords_prods_prods_combined.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered
# ...

# %% [markdown]
# # User-Defined Function

# %%
# Define a User-Defined Function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#Apply the function
df_ords_prods_prods_combined['price_range'] = df_ords_prods_prods_combined.apply(price_label, axis=1)

# %%
df_ords_prods_prods_combined.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
#Output
df_ords_prods_prods_combined['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: price_range, dtype: int64

# %%
df_ords_prods_prods_combined['prices'].max()
# Out:
# 24.5

# %%
#Importing data from 'ords_prods_merged'
path = r'/Users/marialuciaguarita/Python Careerfoundry Project 1'
ords_prods_prods_combined = pd.read_pickle(os.path.join(path,'Data','Prepared Data','orders_products_products_combined.pkl'))

# %%
#Checking imported dataframe and formatting
ords_prods_prods_combined.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'add_to_cart_order',
#        'reordered', '_merge', 'merge_2'],
#       dtype='object')

# %%
ords_prods_prods_combined = ords_prods_prods_combined.drop (columns = ['merge_2','_merge'])

# %%
ords_prods_prods_combined.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered
# ...

# %% [markdown]
# # Loc Function

# %%
# If-Statements with the loc() Function - "Price_label"
ords_prods_prods_combined.loc[ords_prods_prods_combined['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_prods_combined.loc[(ords_prods_prods_combined['prices'] <= 15) & (ords_prods_prods_combined['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_prods_combined.loc[ords_prods_prods_combined['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Output - "Price_label"
ords_prods_prods_combined['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
#Printing the frequency of a column - "Busiest day"
ords_prods_prods_combined['orders_day_of_week'].value_counts(dropna = False )
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
#If-Statements with For-Loops - - "Busiest day"
result = []

for value in ords_prods_prods_combined["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Output - summary column "Busiest day"
ords_prods_prods_combined['busiest_day'] = result
ords_prods_prods_combined['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # If-Statements with For-Loops

# %%
#If-Statements with For-Loops - - "Busiests day"
result = []

for value in ords_prods_prods_combined["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 1:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  elif value == 3:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# Output - summary column "Busiests day"
ords_prods_prods_combined['busiest_day'] = result
ords_prods_prods_combined['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest day       11864412
# Least busy         7624336
# Name: busiest_day, dtype: int64

# %%
#Ords_prods_prods_combined final shape
ords_prods_prods_combined.shape
# Out:
# (32404859, 16)

# %%
#Checking for accuracy with Loc Funtion
ords_prods_prods_combined.loc[ords_prods_prods_combined ['orders_day_of_week'] < 2, 'frequency_of_days_loc'] = 'Busiest_day'

# %%
ords_prods_prods_combined.loc[(ords_prods_prods_combined['orders_day_of_week'] < 5) & (ords_prods_prods_combined['orders_day_of_week'] > 2), 'frequency_of_days_loc'] = 'Least_busy_day'

# %%
#Output - "Frequency_of_days"
ords_prods_prods_combined['frequency_of_days_loc'].value_counts (dropna = False)
# Out:
# NaN               12916111
# Busiest_day       11864412
# Least_busy_day     7624336
# Name: frequency_of_days_loc, dtype: int64

# %%
#Checking for accuracy with print and sum functions
Sum_Busiests_day = ords_prods_prods_combined['orders_day_of_week'].value_counts(dropna = False )

# %%
#Total amount
Sum_Busiests_day.sum()
# Out:
# 32404859

# %%
#Busiest day sum (0,1)
Sum_Busiests_day[:2].sum()
# Out:
# 11864412

# %%
#Least busy days (3,4)
Sum_Busiests_day[5:].sum()
# Out:
# 7624336

# %% [markdown]
# As using both the Loop , and the Loc Function, the result is presented as the sum of the two days with the highest and two days of the lowest movement, it is concluded that the result is correct. Bear in mind that the busiest days have 56% more orders than the two least busy days

# %%
#Printing the frequency of a column - "busiest_period_of_day"
ords_prods_prods_combined['order_hour_of_day'].value_counts(dropna = False )
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# Define a User-Defined Function for 

def busiest_hour(row):

  if (row['order_hour_of_day'] <= 6) or (row['order_hour_of_day'] == 23):
     return 'Fewest orders'
  elif (row['order_hour_of_day'] > 8) and (row['order_hour_of_day'] <= 16):
     return 'Most orders'
  elif (row['order_hour_of_day'] in [7,8,17,18,19,20,21,22]):
     return ' Average orders' 
  else:
    return 'Not enough data'

# %%
#Apply the function
ords_prods_prods_combined ['busiest_period_of_day'] = ords_prods_prods_combined.apply(busiest_hour, axis=1)

# %%
ords_prods_prods_combined ['busiest_period_of_day'].value_counts (dropna = False )
# Out:
# Most orders        21118071
#  Average orders     9997651
# Fewest orders       1289137
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_prods_combined.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
# Exporting as Pickleeuq
ords_prods_prods_combined.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_products_combined2.pkl'))
